# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import seaborn as sns

path='/content/drive/MyDrive/Colab Notebooks/diabetes.csv'
df = pd.read_csv(path)
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 9 columns]

# %%
df['Outcome'].value_counts()
# Out:
# Outcome
# 0    500
# 1    268
# Name: count, dtype: int64

# %%
# 결측치 확인
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
X=df.drop('Outcome',axis=1)
print(X.shape)
# Out:
# (768, 8)

# %%
y=df['Outcome']
y.value_counts()
Y = y.values

# %%
from sklearn.model_selection import train_test_split
X_train,X_test, y_train,y_test = train_test_split(X,Y,test_size=0.2,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
# 1. fit_transform: 훈련 데이터의 평균과 표준편차를 '계산(fit)'하고 바로 '변환(transform)'합니다. 모든 데이터를 평균을 0 표준편차는 1로 변신
X_train = scaler.fit_transform(X_train)

# 2. transform: 중요! 훈련 데이터에서 구한 '그 기준 그대로' 테스트 데이터도 변환합니다.
# (테스트 데이터로 새로 계산하면 안 돼요. 시험 문제는 공부한 기준대로 풀어야 하니까요!)
X_test = scaler.transform(X_test)

# %%
#Defining the model

from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import SGD,Adam

#머신러닝과 딥러닝의 차이는 머신러닝은 특징을 추려낼때 개발자가 개입해야하지만 딥러닝은 그것조차 자신이


model = Sequential()

#노드의 개수를 줄이면서 특징을 추려나가는 과정

model.add(Dense(8,input_shape=(8,),activation='relu'))
model.add(Dense(6,activation='relu'))
model.add(Dense(4,activation='relu'))
model.add(Dense(1, activation='sigmoid'))

#결과가 2종류길래 1에 sigmoid, binary_Crosssentropy를씀
#sigmoid는 값을 하나 주면 1에서 그 값을 뺀 값이 나머지 경우의 확률이 되는 방식임

model.compile(Adam(learning_rate=0.001),'binary_crossentropy',metrics=['accuracy'])


model.summary()
# Out:
# Model: "sequential_10"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_40 (Dense)                │ (None, 8)              │            72 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_41 (Dense)                │ (None, 6)              │            54 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_42 (Dense)                │ (None, 4)              │            28 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_43 (Dense)                │ (None, 1)              │             5 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 159 (636.00 B)
#  Trainable params: 159 (636.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
model_history=model.fit(x=X_train, y=y_train, epochs=50, batch_size=32,validation_data= (X_test,y_test))
y_pred = model.predict(X_test)
#argmax는 옆으로 가면서 가장 큰 값을 찾아주는건데 dense가 1이기 때문에 갈 곳이 없음
y_test_class = y_test
y_pred_class = (y_pred > 0.5).astype(int)
# Out:
# Epoch 1/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.6287 - loss: 0.7022 - val_accuracy: 0.6364 - val_loss: 0.6708
# Epoch 2/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6515 - loss: 0.6779 - val_accuracy: 0.6688 - val_loss: 0.6513
# Epoch 3/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6645 - loss: 0.6560 - val_accuracy: 0.6883 - val_loss: 0.6320
# Epoch 4/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6694 - loss: 0.6347 - val_accuracy: 0.7078 - val_loss: 0.6047
# Epoch 5/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6857 - loss: 0.6131 - val_accuracy: 0.7143 - val_loss: 0.5804
# Epoch 6/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7003 - loss: 0.5925 - val_accuracy: 0.7468 - val_loss: 0.5593
# Epoch 7/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7052 - loss: 0.5729 - val_accuracy: 0.7662 - val_loss: 0.5390
# Epoch 8/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7215 - loss: 0.5544 - val_accuracy: 0.7662 - val_loss: 0.5195
# Epoch 9/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7182 - loss: 0.5389 - val_accuracy: 0.7727 - val_loss: 0.5066
# Epoch 10/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7313 - loss: 0.5257 - val_accuracy: 0.7662 - val_loss: 0.4950
# Epoch 11/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7378 - loss: 0.5141 - val_accuracy: 0.7662 - val_loss: 0.4877
# Epoch 12/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7329 - loss: 0.5063 - val_accuracy: 0.7662 - val_loss: 0.4805
# Epoch 13/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7313 - loss: 0.4998 - val_accuracy: 0.7792 - val_loss: 0.4749
# Epoch 14/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7443 - loss: 0.4946 - val_accuracy: 0.7922 - val_loss: 0.4664
# Epoch 15/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7492 - loss: 0.4899 - val_accuracy: 0.7922 - val_loss: 0.4598
# Epoch 16/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7492 - loss: 0.4861 - val_accuracy: 0.7987 - val_loss: 0.4565
# Epoch 17/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7508 - loss: 0.4817 - val_accuracy: 0.7987 - val_loss: 0.4525
# Epoch 18/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7492 - loss: 0.4789 - val_accuracy: 0.7922 - val_loss: 0.4542
# Epoch 19/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7524 - loss: 0.4754 - val_accuracy: 0.8117 - val_loss: 0.4460
# Epoch 20/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7508 - loss: 0.4729 - val_accuracy: 0.7987 - val_loss: 0.4476
# Epoch 21/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7590 - loss: 0.4718 - val_accuracy: 0.7922 - val_loss: 0.4509
# Epoch 22/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7606 - loss: 0.4702 - val_accuracy: 0.7922 - val_loss: 0.4485
# Epoch 23/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7557 - loss: 0.4687 - val_accuracy: 0.8182 - val_loss: 0.4430
# Epoch 24/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7590 - loss: 0.4671 - val_accuracy: 0.8117 - val_loss: 0.4434
# Epoch 25/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7590 - loss: 0.4656 - val_accuracy: 0.8117 - val_loss: 0.4427
# Epoch 26/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7573 - loss: 0.4644 - val_accuracy: 0.8117 - val_loss: 0.4423
# Epoch 27/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7606 - loss: 0.4635 - val_accuracy: 0.8182 - val_loss: 0.4402
# Epoch 28/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7590 - loss: 0.4627 - val_accuracy: 0.7987 - val_loss: 0.4416
# Epoch 29/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7590 - loss: 0.4618 - val_accuracy: 0.8052 - val_loss: 0.4397
# Epoch 30/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7590 - loss: 0.4608 - val_accuracy: 0.8052 - val_loss: 0.4391
# Epoch 31/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7622 - loss: 0.4605 - val_accuracy: 0.8052 - val_loss: 0.4400
# Epoch 32/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7606 - loss: 0.4596 - val_accuracy: 0.8052 - val_loss: 0.4384
# Epoch 33/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7638 - loss: 0.4590 - val_accuracy: 0.8117 - val_loss: 0.4404
# Epoch 34/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7606 - loss: 0.4583 - val_accuracy: 0.8052 - val_loss: 0.4393
# Epoch 35/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7606 - loss: 0.4582 - val_accuracy: 0.8117 - val_loss: 0.4377
# Epoch 36/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7638 - loss: 0.4576 - val_accuracy: 0.8117 - val_loss: 0.4386
# Epoch 37/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7638 - loss: 0.4568 - val_accuracy: 0.8117 - val_loss: 0.4399
# Epoch 38/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7590 - loss: 0.4565 - val_accuracy: 0.8182 - val_loss: 0.4435
# Epoch 39/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7622 - loss: 0.4555 - val_accuracy: 0.8247 - val_loss: 0.4404
# Epoch 40/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7622 - loss: 0.4552 - val_accuracy: 0.8247 - val_loss: 0.4408
# Epoch 41/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7638 - loss: 0.4546 - val_accuracy: 0.8312 - val_loss: 0.4368
# Epoch 42/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7590 - loss: 0.4541 - val_accuracy: 0.8247 - val_loss: 0.4389
# Epoch 43/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7606 - loss: 0.4547 - val_accuracy: 0.8312 - val_loss: 0.4342
# Epoch 44/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7622 - loss: 0.4533 - val_accuracy: 0.8247 - val_loss: 0.4402
# Epoch 45/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7622 - loss: 0.4529 - val_accuracy: 0.8247 - val_loss: 0.4413
# Epoch 46/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7622 - loss: 0.4529 - val_accuracy: 0.8312 - val_loss: 0.4363
# Epoch 47/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7638 - loss: 0.4521 - val_accuracy: 0.8312 - val_loss: 0.4364
# Epoch 48/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7606 - loss: 0.4512 - val_accuracy: 0.8182 - val_loss: 0.4435
# Epoch 49/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7590 - loss: 0.4514 - val_accuracy: 0.8247 - val_loss: 0.4387
# Epoch 50/50
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7606 - loss: 0.4509 - val_accuracy: 0.8312 - val_loss: 0.4404
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step

# %%
import matplotlib.pyplot as plt
import seaborn as sns

loss =model_history.history['loss']
val_loss =model_history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
acc =model_history.history['accuracy']
val_acc =model_history.history['val_accuracy']
plt.plot(epochs, acc, 'y', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
#Accuracy of the predicted values
from sklearn.metrics import classification_report,confusion_matrix
print(classification_report(y_test_class,y_pred_class))
print(confusion_matrix(y_test_class,y_pred_class))
#정밀도:모델이 맞다고 말한것 중에서 실제로 맞은거
#재현율:실제 True인 것 중에서 모델이 True라고 예측한 것
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.88      0.88       107
#            1       0.72      0.72      0.72        47
#
#     accuracy                           0.83       154
#    macro avg       0.80      0.80      0.80       154
# weighted avg       0.83      0.83      0.83       154
#
# [[94 13]
#  [13 34]]
