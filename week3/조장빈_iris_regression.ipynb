# %%
import pandas as pd
import numpy as np
from sklearn import datasets

# 1. 데이터 가져오기
iris = datasets.load_iris()

# 2. 수치 데이터만 들어있는 데이터프레임 만들기 (target은 안 넣음!)
df = pd.DataFrame(data=iris.data, columns=iris.feature_names)

# 3. 정답(y)과 문제(X) 나누기
y = df['petal width (cm)']
X = df.drop('petal width (cm)', axis=1)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.45,random_state=0)

from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

model = LinearRegression()
model.fit(X_train, y_train)
ly_preds = model.predict(X_test)

print('평균제곱근오차', mean_squared_error(ly_preds, y_test))

def mse_np(actual, predicted):
    return np.mean((np.array(actual) - np.array(predicted)) ** 2)

print('평균제곱근오차', mse_np(ly_preds, y_test))

def mse(actual, predicted):
    sum_square_error = sum((a - p) ** 2 for a, p in zip(actual, predicted))
    mean_square_error = sum_square_error / len(actual)
    return mean_square_error

print('평균제곱근오차', mse(ly_preds, y_test))
# Out:
# 평균제곱근오차 0.044290682597708506
# 평균제곱근오차 0.044290682597708506
# 평균제곱근오차 0.04429068259770851

# %%
from sklearn.tree import DecisionTreeRegressor

model = DecisionTreeRegressor()
model.fit(X_train, y_train)

from sklearn.metrics import mean_squared_error

dy_preds = model.predict(X_test)
print('평균제곱근오차', mean_squared_error(dy_preds, y_test))
# Out:
# 평균제곱근오차 0.05238970588235294

# %%
from sklearn.ensemble import RandomForestRegressor

model = RandomForestRegressor()
model.fit(X_train, y_train)

from sklearn.metrics import mean_squared_error

ry_preds = model.predict(X_test)
print('평균제곱근오차', mean_squared_error(ry_preds, y_test))
# Out:
# 평균제곱근오차 0.04736216098651969

# %%
from sklearn.neighbors import KNeighborsRegressor

knn = KNeighborsRegressor(n_neighbors=7)
knn.fit(X_train, y_train)
ky_preds = knn.predict(X_test)

print('평균제곱오차(MSE):', mean_squared_error(ky_preds, y_test))
# Out:
# 평균제곱오차(MSE): 0.04521308523409363
